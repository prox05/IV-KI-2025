# %% [markdown]
# # Main Visualisation Notebook
# Dit is het hoofd notebook

# %%
import plotly.graph_objs as go
import plotly.express as px
import pandas as pd

from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>

# %%
# df_food_prices = pd.read_csv('/dataset_sources/Food_Prices.csv')
# df_food_prices_sweden = df_food_prices[df_food_prices['Country '] == 'Sweden'].drop('Country ', axis=1)
# df_food_prices_sweden.to_csv('/filtered/Food_Prices_Sweden.csv', index=False)
df_food_prices_sweden = pd.read_csv('filtered/Food_Prices_Sweden.csv')
df_food_prices_sweden.info()
# df_food_prices_sweden.describe()
df_food_prices_sweden.head(n=5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 240 non-null    int64
#  1   Month                240 non-null    int64
#  2   Food Item            240 non-null    object
#  3   Unit of Measurement  240 non-null    object
#  4   Average Price        240 non-null    float64
#  5   Currency             240 non-null    object
#  6   Price in USD         240 non-null    float64
#  7   Availability         240 non-null    int64
#  8   Quality              240 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 17.0+ KB
#    Year   Month  Food Item  Unit of Measurement  Average Price  Currency   \
# 0   2018       1      Bread                Loaf           18.61        Kr
# 1   2018       2      Bread                Loaf           18.66        Kr
# 2   2018       3      Bread                Loaf           18.71        Kr
# 3   2018       4      Bread                Loaf           18.76        Kr
# 4   2018       5      Bread                Loaf           18.81        Kr
#
#    Price in USD  Availability  Quality
# 0          1.82              1     High
# 1          1.83              1     High
# 2          1.83              1     High
# 3          1.84              1     High
# 4          1.84              1     High

# %%
# df_wdi_indicators = pd.read_csv('/dataset_sources/WDI_Indicators_MainData.csv')
# df_wdi_indicators_sweden = df_wdi_indicators[df_wdi_indicators['Country Name'] == 'Sweden'].drop('Country Name', axis=1).drop('Country Code', axis=1)
# df_wdi_indicators_sweden.to_csv("/filtered/WDI_Indicators_Sweden.csv", index=False)
df_wdi_indicators_sweden = pd.read_csv('filtered/WDI_Indicators_Sweden.csv')
df_wdi_indicators_sweden.info()
# df_wdi_indicators_sweden.describe()
df_wdi_indicators_sweden.head(n=5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 93 columns):
#  #   Column                                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                                        --------------  -----
#  0   Time                                                                                                                                          11 non-null     int64
#  1   Time Code                                                                                                                                     11 non-null     object
#  2   Current education expenditure, primary (% of total expenditure in primary public institutions) [SE.XPD.CPRM.ZS]                               11 non-null     float64
#  3   Current education expenditure, secondary (% of total expenditure in secondary public institutions) [SE.XPD.CSEC.ZS]                           11 non-null     float64
#  4   Current education expenditure, tertiary (% of total expenditure in tertiary public institutions) [SE.XPD.CTER.ZS]                             11 non-null     float64
#  5   Current education expenditure, total (% of total expenditure in public institutions) [SE.XPD.CTOT.ZS]                                         11 non-null     float64
#  6   Current health expenditure (% of GDP) [SH.XPD.CHEX.GD.ZS]                                                                                     11 non-null     float64
#  7   Domestic general government health expenditure (% of GDP) [SH.XPD.GHED.GD.ZS]                                                                 11 non-null     float64
#  8   Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative) [SE.TER.CUAT.BA.FE.ZS]                     11 non-null     float64
#  9   Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative) [SE.TER.CUAT.BA.MA.ZS]                       11 non-null     float64
#  10  Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative) [SE.TER.CUAT.BA.ZS]                         11 non-null     float64
#  11  Educational attainment, at least completed lower secondary, population 25+, female (%) (cumulative) [SE.SEC.CUAT.LO.FE.ZS]                    11 non-null     float64
#  12  Educational attainment, at least completed lower secondary, population 25+, male (%) (cumulative) [SE.SEC.CUAT.LO.MA.ZS]                      11 non-null     float64
#  13  Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative) [SE.SEC.CUAT.LO.ZS]                        11 non-null     float64
#  14  Educational attainment, at least completed post-secondary, population 25+, female (%) (cumulative) [SE.SEC.CUAT.PO.FE.ZS]                     11 non-null     float64
#  15  Educational attainment, at least completed post-secondary, population 25+, male (%) (cumulative) [SE.SEC.CUAT.PO.MA.ZS]                       11 non-null     float64
#  16  Educational attainment, at least completed post-secondary, population 25+, total (%) (cumulative) [SE.SEC.CUAT.PO.ZS]                         11 non-null     float64
#  17  Educational attainment, at least completed primary, population 25+ years, female (%) (cumulative) [SE.PRM.CUAT.FE.ZS]                         11 non-null     float64
#  18  Educational attainment, at least completed primary, population 25+ years, male (%) (cumulative) [SE.PRM.CUAT.MA.ZS]                           11 non-null     float64
#  19  Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative) [SE.PRM.CUAT.ZS]                             11 non-null     float64
#  20  Educational attainment, at least completed short-cycle tertiary, population 25+, female (%) (cumulative) [SE.TER.CUAT.ST.FE.ZS]               11 non-null     float64
#  21  Educational attainment, at least completed short-cycle tertiary, population 25+, male (%) (cumulative) [SE.TER.CUAT.ST.MA.ZS]                 11 non-null     float64
#  22  Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative) [SE.TER.CUAT.ST.ZS]                   11 non-null     float64
#  23  Educational attainment, at least completed upper secondary, population 25+, female (%) (cumulative) [SE.SEC.CUAT.UP.FE.ZS]                    11 non-null     float64
#  24  Educational attainment, at least completed upper secondary, population 25+, male (%) (cumulative) [SE.SEC.CUAT.UP.MA.ZS]                      11 non-null     float64
#  25  Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative) [SE.SEC.CUAT.UP.ZS]                        11 non-null     float64
#  26  Educational attainment, at least Master's or equivalent, population 25+, female (%) (cumulative) [SE.TER.CUAT.MS.FE.ZS]                       11 non-null     float64
#  27  Educational attainment, at least Master's or equivalent, population 25+, male (%) (cumulative) [SE.TER.CUAT.MS.MA.ZS]                         11 non-null     float64
#  28  Educational attainment, at least Master's or equivalent, population 25+, total (%) (cumulative) [SE.TER.CUAT.MS.ZS]                           11 non-null     float64
#  29  Educational attainment, Doctoral or equivalent, population 25+, female (%) (cumulative) [SE.TER.CUAT.DO.FE.ZS]                                11 non-null     float64
#  30  Educational attainment, Doctoral or equivalent, population 25+, male (%) (cumulative) [SE.TER.CUAT.DO.MA.ZS]                                  11 non-null     float64
#  31  Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative) [SE.TER.CUAT.DO.ZS]                                    11 non-null     float64
#  32  Employers, female (% of female employment) (modeled ILO estimate) [SL.EMP.MPYR.FE.ZS]                                                         11 non-null     float64
#  33  Employers, male (% of male employment) (modeled ILO estimate) [SL.EMP.MPYR.MA.ZS]                                                             11 non-null     float64
#  34  Employers, total (% of total employment) (modeled ILO estimate) [SL.EMP.MPYR.ZS]                                                              11 non-null     float64
#  35  Employment in agriculture (% of total employment) (modeled ILO estimate) [SL.AGR.EMPL.ZS]                                                     11 non-null     float64
#  36  Employment in agriculture, female (% of female employment) (modeled ILO estimate) [SL.AGR.EMPL.FE.ZS]                                         11 non-null     float64
#  37  Employment in agriculture, male (% of male employment) (modeled ILO estimate) [SL.AGR.EMPL.MA.ZS]                                             11 non-null     float64
#  38  Employment in industry (% of total employment) (modeled ILO estimate) [SL.IND.EMPL.ZS]                                                        11 non-null     float64
#  39  Employment in industry, female (% of female employment) (modeled ILO estimate) [SL.IND.EMPL.FE.ZS]                                            11 non-null     float64
#  40  Employment in industry, male (% of male employment) (modeled ILO estimate) [SL.IND.EMPL.MA.ZS]                                                11 non-null     float64
#  41  Employment in services (% of total employment) (modeled ILO estimate) [SL.SRV.EMPL.ZS]                                                        11 non-null     float64
#  42  Employment in services, female (% of female employment) (modeled ILO estimate) [SL.SRV.EMPL.FE.ZS]                                            11 non-null     float64
#  43  Employment in services, male (% of male employment) (modeled ILO estimate) [SL.SRV.EMPL.MA.ZS]                                                11 non-null     float64
#  44  Employment to population ratio, 15+, female (%) (modeled ILO estimate) [SL.EMP.TOTL.SP.FE.ZS]                                                 11 non-null     float64
#  45  Employment to population ratio, 15+, male (%) (modeled ILO estimate) [SL.EMP.TOTL.SP.MA.ZS]                                                   11 non-null     float64
#  46  Employment to population ratio, 15+, total (%) (modeled ILO estimate) [SL.EMP.TOTL.SP.ZS]                                                     11 non-null     float64
#  47  Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate) [SL.EMP.1524.SP.FE.ZS]                                          11 non-null     float64
#  48  Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate) [SL.EMP.1524.SP.MA.ZS]                                            11 non-null     float64
#  49  Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate) [SL.EMP.1524.SP.ZS]                                              11 non-null     float64
#  50  Hospital beds (per 1,000 people) [SH.MED.BEDS.ZS]                                                                                             10 non-null     float64
#  51  International migrant stock (% of population) [SM.POP.TOTL.ZS]                                                                                1 non-null      float64
#  52  Net migration [SM.POP.NETM]                                                                                                                   11 non-null     int64
#  53  Nurses and midwives (per 1,000 people) [SH.MED.NUMW.P3]                                                                                       10 non-null     float64
#  54  Part time employment, female (% of total female employment) [SL.TLF.PART.FE.ZS]                                                               11 non-null     float64
#  55  Part time employment, male (% of total male employment) [SL.TLF.PART.MA.ZS]                                                                   11 non-null     float64
#  56  Part time employment, total (% of total employment) [SL.TLF.PART.ZS]                                                                          11 non-null     float64
#  57  Physicians (per 1,000 people) [SH.MED.PHYS.ZS]                                                                                                10 non-null     float64
#  58  Population growth (annual %) [SP.POP.GROW]                                                                                                    11 non-null     float64
#  59  Population, female [SP.POP.TOTL.FE.IN]                                                                                                        11 non-null     int64
#  60  Population, male [SP.POP.TOTL.MA.IN]                                                                                                          11 non-null     int64
#  61  Population, total [SP.POP.TOTL]                                                                                                               11 non-null     int64
#  62  Research and development expenditure (% of GDP) [GB.XPD.RSDV.GD.ZS]                                                                           11 non-null     float64
#  63  Researchers in R&D (per million people) [SP.POP.SCIE.RD.P6]                                                                                   11 non-null     float64
#  64  Scientific and technical journal articles [IP.JRN.ARTC.SC]                                                                                    11 non-null     float64
#  65  Self-employed, female (% of female employment) (modeled ILO estimate) [SL.EMP.SELF.FE.ZS]                                                     11 non-null     float64
#  66  Self-employed, male (% of male employment) (modeled ILO estimate) [SL.EMP.SELF.MA.ZS]                                                         11 non-null     float64
#  67  Self-employed, total (% of total employment) (modeled ILO estimate) [SL.EMP.SELF.ZS]                                                          11 non-null     float64
#  68  Share of youth not in education, employment or training, female (% of female youth population) (modeled ILO estimate) [SL.UEM.NEET.FE.ME.ZS]  11 non-null     float64
#  69  Share of youth not in education, employment or training, male (% of male youth population)  (modeled ILO estimate) [SL.UEM.NEET.MA.ME.ZS]     11 non-null     float64
#  70  Share of youth not in education, employment or training, total (% of youth population)  (modeled ILO estimate) [SL.UEM.NEET.ME.ZS]            11 non-null     float64
#  71  Survival to age 65, female (% of cohort) [SP.DYN.TO65.FE.ZS]                                                                                  11 non-null     float64
#  72  Survival to age 65, male (% of cohort) [SP.DYN.TO65.MA.ZS]                                                                                    11 non-null     float64
#  73  Unemployment with advanced education, female (% of female labor force with advanced education) [SL.UEM.ADVN.FE.ZS]                            11 non-null     float64
#  74  Unemployment with advanced education, male (% of male labor force with advanced education) [SL.UEM.ADVN.MA.ZS]                                11 non-null     float64
#  75  Unemployment with basic education (% of total labor force with basic education) [SL.UEM.BASC.ZS]                                              11 non-null     float64
#  76  Unemployment with basic education, female (% of female labor force with basic education) [SL.UEM.BASC.FE.ZS]                                  11 non-null     float64
#  77  Unemployment with basic education, male (% of male labor force with basic education) [SL.UEM.BASC.MA.ZS]                                      11 non-null     float64
#  78  Unemployment with intermediate education (% of total labor force with intermediate education) [SL.UEM.INTM.ZS]                                11 non-null     float64
#  79  Unemployment with intermediate education, female (% of female labor force with intermediate education) [SL.UEM.INTM.FE.ZS]                    11 non-null     float64
#  80  Unemployment with intermediate education, male (% of male labor force with intermediate education) [SL.UEM.INTM.MA.ZS]                        11 non-null     float64
#  81  Unemployment, female (% of female labor force) (modeled ILO estimate) [SL.UEM.TOTL.FE.ZS]                                                     11 non-null     float64
#  82  Unemployment, male (% of male labor force) (modeled ILO estimate) [SL.UEM.TOTL.MA.ZS]                                                         11 non-null     float64
#  83  Unemployment, total (% of total labor force) (modeled ILO estimate) [SL.UEM.TOTL.ZS]                                                          11 non-null     float64
#  84  Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate) [SL.UEM.1524.FE.ZS]                                    11 non-null     float64
#  85  Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate) [SL.UEM.1524.MA.ZS]                                        11 non-null     float64
#  86  Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate) [SL.UEM.1524.ZS]                                         11 non-null     float64
#  87  Vulnerable employment, female (% of female employment) (modeled ILO estimate) [SL.EMP.VULN.FE.ZS]                                             11 non-null     float64
#  88  Vulnerable employment, male (% of male employment) (modeled ILO estimate) [SL.EMP.VULN.MA.ZS]                                                 11 non-null     float64
#  89  Vulnerable employment, total (% of total employment) (modeled ILO estimate) [SL.EMP.VULN.ZS]                                                  11 non-null     float64
#  90  Wage and salaried workers, female (% of female employment) (modeled ILO estimate) [SL.EMP.WORK.FE.ZS]                                         11 non-null     float64
#  91  Wage and salaried workers, male (% of male employment) (modeled ILO estimate) [SL.EMP.WORK.MA.ZS]                                             11 non-null     float64
#  92  Wage and salaried workers, total (% of total employment) (modeled ILO estimate) [SL.EMP.WORK.ZS]                                              11 non-null     float64
# dtypes: float64(87), int64(5), object(1)
# memory usage: 8.1+ KB
#    Time Time Code  \
# 0  2011    YR2011
# 1  2012    YR2012
# 2  2013    YR2013
# 3  2014    YR2014
# 4  2015    YR2015
#
#    Current education expenditure, primary (% of total expenditure in primary public institutions) [SE.XPD.CPRM.ZS]  \
# 0                                          93.548080
# 1                                          93.414368
# 2                                          94.069023
# 3                                          94.294456
# 4                                          94.451561
#
#    Current education expenditure, secondary (% of total expenditure in secondary public institutions) [SE.XPD.CSEC.ZS]  \
# 0                                          92.387177
# 1                                          92.748329
# 2                                          93.433868
# 3                                          93.243660
# 4                                          93.581108
#
#    Current education expenditure, tertiary (% of total expenditure in tertiary public institutions) [SE.XPD.CTER.ZS]  \
# 0                                          96.735512
# 1                                          96.636200
# 2                                          96.626732
# 3                                          96.539963
# 4                                          96.397507
#
#    Current education expenditure, total (% of total expenditure in public institutions) [SE.XPD.CTOT.ZS]  \
# 0                                          94.218224
# 1                                          94.350578
# 2                                          94.933533
# 3                                          94.891449
# 4                                          94.913559
#
#    Current health expenditure (% of GDP) [SH.XPD.CHEX.GD.ZS]  \
# 0                                              10.42
# 1                                              10.74
# 2                                              10.90
# 3                                              10.95
# 4                                              10.80
#
#    Domestic general government health expenditure (% of GDP) [SH.XPD.GHED.GD.ZS]  \
# 0                                               8.80
# 1                                               9.04
# 2                                               9.16
# 3                                               9.20
# 4                                               9.07
#
#    Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative) [SE.TER.CUAT.BA.FE.ZS]  \
# 0                                           1.043066
# 1                                           1.082311
# 2                                          24.990000
# 3                                          25.660000
# 4                                          26.299999
#
#    Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative) [SE.TER.CUAT.BA.MA.ZS]  \
# 0                                           1.601204
# 1                                           1.553720
# 2                                          19.000000
# 3                                          19.320000
# 4                                          19.610001
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate) [SL.UEM.TOTL.ZS]  \
# 0                                              7.804
# 1                                              7.976
# 2                                              8.052
# 3                                              7.954
# 4                                              7.432
#
#    Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate) [SL.UEM.1524.FE.ZS]  \
# 0                                             22.264
# 1                                             22.199
# 2                                             22.273
# 3                                             21.432
# 4                                             19.536
#
#    Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate) [SL.UEM.1524.MA.ZS]  \
# 0                                             23.274
# 1                                             24.990
# 2                                             24.726
# 3                                             24.161
# 4                                             21.180
#
#    Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate) [SL.UEM.1524.ZS]  \
# 0                                             22.784
# 1                                             23.609
# 2                                             23.519
# 3                                             22.822
# 4                                             20.365
#
#    Vulnerable employment, female (% of female employment) (modeled ILO estimate) [SL.EMP.VULN.FE.ZS]  \
# 0                                           4.334885
# 1                                           4.409921
# 2                                           4.455857
# 3                                           4.406226
# 4                                           4.404664
#
#    Vulnerable employment, male (% of male employment) (modeled ILO estimate) [SL.EMP.VULN.MA.ZS]  \
# 0                                           9.508193
# 1                                           9.526058
# 2                                           9.659157
# 3                                           9.380237
# 4                                           9.280488
#
#    Vulnerable employment, total (% of total employment) (modeled ILO estimate) [SL.EMP.VULN.ZS]  \
# 0                                           7.060419
# 1                                           7.092931
# 2                                           7.184854
# 3                                           7.011152
# 4                                           6.954681
#
#    Wage and salaried workers, female (% of female employment) (modeled ILO estimate) [SL.EMP.WORK.FE.ZS]  \
# 0                                          94.115397
# 1                                          94.029428
# 2                                          93.946155
# 3                                          94.022379
# 4                                          94.010933
#
#    Wage and salaried workers, male (% of male employment) (modeled ILO estimate) [SL.EMP.WORK.MA.ZS]  \
# 0                                          85.506837
# 1                                          85.482927
# 2                                          85.294918
# 3                                          85.700021
# 4                                          85.845618
#
#    Wage and salaried workers, total (% of total employment) (modeled ILO estimate) [SL.EMP.WORK.ZS]
# 0                                          89.580016
# 1                                          89.547485
# 2                                          89.408790
# 3                                          89.663843
# 4                                          89.740538
#
# [5 rows x 93 columns]

# %%
# df_annual_net_earnings = pd.read_csv('/dataset_sources/estat_earn_nt_net_en.csv')
# df_annual_net_earnings_sweden = df_annual_net_earnings[df_annual_net_earnings['geo'] == 'Sweden'].drop('geo', axis=1)
# df_annual_net_earnings_sweden.to_csv('/filtered/Annual_Net_Earnings_Sweden.csv', index=False)
df_annual_net_earnings_sweden = pd.read_csv('filtered/Annual_Net_Earnings_Sweden.csv')
df_annual_net_earnings_sweden.info()
# df_annual_net_earnings_sweden.describe()
df_annual_net_earnings_sweden.head(n=5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5742 entries, 0 to 5741
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATAFLOW     5742 non-null   object
#  1   LAST UPDATE  5742 non-null   object
#  2   freq         5742 non-null   object
#  3   currency     5742 non-null   object
#  4   estruct      5742 non-null   object
#  5   ecase        5742 non-null   object
#  6   TIME_PERIOD  5742 non-null   int64
#  7   OBS_VALUE    5742 non-null   float64
#  8   OBS_FLAG     0 non-null      float64
#  9   CONF_STATUS  0 non-null      float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 448.7+ KB
#                  DATAFLOW        LAST UPDATE    freq currency  \
# 0  ESTAT:EARN_NT_NET(1.0)  29/04/25 23:00:00  Annual     Euro
# 1  ESTAT:EARN_NT_NET(1.0)  29/04/25 23:00:00  Annual     Euro
# 2  ESTAT:EARN_NT_NET(1.0)  29/04/25 23:00:00  Annual     Euro
# 3  ESTAT:EARN_NT_NET(1.0)  29/04/25 23:00:00  Annual     Euro
# 4  ESTAT:EARN_NT_NET(1.0)  29/04/25 23:00:00  Annual     Euro
#
#              estruct                                              ecase  \
# 0  Family allowances  One-earner couple with two children earning 10...
# 1  Family allowances  One-earner couple with two children earning 10...
# 2  Family allowances  One-earner couple with two children earning 10...
# 3  Family allowances  One-earner couple with two children earning 10...
# 4  Family allowances  One-earner couple with two children earning 10...
#
#    TIME_PERIOD  OBS_VALUE  OBS_FLAG  CONF_STATUS
# 0         2000    2415.57       NaN          NaN
# 1         2001    2463.51       NaN          NaN
# 2         2002    2488.78       NaN          NaN
# 3         2003    2498.85       NaN          NaN
# 4         2004    2498.82       NaN          NaN

# %% [markdown]
# # Options visualisation
# - Multibar chart showing net income through the years for a view categories
# - Distribution income sources donut chart maybe
# - Food Prices per product or per category aka essential (bread) and luxury food
# - Line chart comparing income and food prices
# need more
#
# **Gebruik Lecture 4-4 pagina 11** om te kijken wat voor plot het beste past.
